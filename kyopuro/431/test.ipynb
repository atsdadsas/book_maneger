# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a,b,c,d=map(int,input().split())
#       2 if c>=a and b>d:
#       3     print("Yes")
#
# ValueError: not enough values to unpack (expected 4, got 0)

# %% [markdown]
# 良問
#
# 高橋君の住む AtCoder 国には「飴を
# A 個以上所持している人はクッキーを
# B 個以上所持していなければならない」という奇妙な法律があります。
#
# 高橋君は飴を
# C 個、クッキーを
# D 個所持しています。高橋君がこの法律に違反しているかどうか判定してください。

# %%
a,b,c,d=map(int,input().split())
if c>=a and b>d:
    print("Yes")
else:
    print("No")

# %%
n,m=map(int,input().split())
for i in range(n):
    sl=list(int,input().split())
    sn=[]
    sn.append(sl)
